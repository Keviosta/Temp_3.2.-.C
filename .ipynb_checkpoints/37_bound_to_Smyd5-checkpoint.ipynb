# %% [markdown]
# # Import, options

# %%
import numpy, seaborn, pandas
import matplotlib, matplotlib.pyplot as plt

# %%
matplotlib.rcParams.update({'font.size':20, 'xtick.labelsize':20, 'ytick.labelsize':20, 
                            'axes.grid' : True, 'grid.alpha': 0.5, 'grid.linestyle' : ':',
                            'figure.figsize':(8, 5), 'svg.fonttype' : 'none'})

# %%
file_directory = "/Users/kja11/OneDrive - Menntaský/PostDoc_Hypothermia/in_silico/Python/"

# %% [markdown]
# # Data Downloads

# %%
# %%time
#data mouse_NPC
mouse_NPC_df = pandas.read_csv(file_directory+'1) input/mNPC_all_detected_genes_DEseq.csv',
                               sep = ',')
print(mouse_NPC_df.shape)
mouse_NPC_df
# Out:
# (16062, 15)
# CPU times: total: 31.2 ms
# Wall time: 71.8 ms
#                 Row.names      baseMean  log2FoldChange     lfcSE       stat  \
# 0      ENSMUSG00000045193   3816.986957        2.021396  0.078809  25.649295
# 1      ENSMUSG00000020484   1432.209485       -1.884029  0.074767 -25.198770
# 2      ENSMUSG00000015656  70154.077373       -1.231949  0.060548 -20.346671
# 3      ENSMUSG00000004069   1746.313298       -1.053931  0.057622 -18.290502
# 4      ENSMUSG00000029817   1437.967304       -2.158750  0.123641 -17.459869
# ...                   ...           ...             ...       ...        ...
# 16057  ENSMUSG00000040374   1689.634000        0.000098  0.094263   0.001040
# 16058  ENSMUSG00000069601    852.924300       -0.000171  0.196786  -0.000869
# 16059  ENSMUSG00000028672   1076.073000        0.000057  0.090005   0.000633
# 16060  ENSMUSG00000035199   1357.066000        0.000070  0.107616   0.000653
# 16061  ENSMUSG00000040560    126.494700       -0.000116  1.494583  -0.000077
#
#               pvalue           padj     gene    37_degrees   37_degrees.1  \
# 0      4.305259e-145  6.939647e-141    Cirbp   1298.248488    1409.083082
# 1      4.131947e-140  3.330143e-136     Xbp1   2374.305284    2549.824828
# 2       4.968957e-92   2.669821e-88    Hspa8  97554.350098  109665.742969
# 3       9.850430e-75   3.969477e-71   Dnaja3   2468.307855    2501.951919
# 4       2.895976e-68   9.336048e-65    Tra2a   2300.530277    2712.435356
# ...              ...            ...      ...           ...            ...
# 16057   9.991703e-01   9.994484e-01     Pex2   1770.350000    1611.318000
# 16058   9.993065e-01   9.994925e-01     Ank3    543.605700    1031.159000
# 16059   9.994949e-01   9.995569e-01    Hmgcl   1181.231000     975.912000
# 16060   9.994792e-01   9.995569e-01  Arl6ip5   1161.610000    1415.048000
# 16061   9.999382e-01   9.999382e-01     Wdr7    248.373400       0.000000
#
#         37_degrees.2    32_degrees  32_degrees.1  32_degrees.2  32_degrees.3
# 0        1456.275302   6117.014966   5155.322063   5886.014969   5396.949830
# 1        2437.413637    683.013572    668.546151    700.131803    612.231119
# 2      106033.053662  46940.696119  43593.055672  45443.791959  41847.851131
# 3        2474.955659   1225.709230   1163.293883   1185.274805   1204.699735
# 4        2735.069730    652.603893    620.523550    590.851333    453.756987
# ...              ...           ...           ...           ...           ...
# 16057    1685.100000   1629.899000   1835.107000   1833.215000   1462.453000
# 16058     984.529200    990.711700    794.611200    910.848200    715.005000
# 16059    1074.131000   1115.568000    995.605900   1094.933000   1095.132000
# 16060    1490.163000   1355.401000   1512.990000   1346.521000   1217.732000
# 16061     131.242400    162.290500    100.989900     74.985460    167.580800
#
# [16062 rows x 15 columns]

# %%
# download the Smyd5 bound list
with open(file_directory+'1) input/SMYD5_bound_list.txt') as f:
    SMYD5_bound_list = f.read().splitlines()

# %%
print(len(SMYD5_bound_list))
selected_df = mouse_NPC_df[mouse_NPC_df['gene'].isin(SMYD5_bound_list)].copy()
print(len(selected_df))
selected_df.head()
# Out:
# 37
# 37
#                Row.names      baseMean  log2FoldChange     lfcSE       stat  \
# 94    ENSMUSG00000017861   2655.879077        0.709024  0.062492  11.345835
# 287   ENSMUSG00000030087    355.909699        1.162393  0.135688   8.566648
# 400   ENSMUSG00000043962  12539.021300        0.356678  0.045367   7.862097
# 1064  ENSMUSG00000009628    338.935012        0.731618  0.126576   5.780071
# 1239  ENSMUSG00000009079  14576.109554        0.237480  0.043754   5.427568
#
#             pvalue          padj    gene    37_degrees  37_degrees.1  \
# 94    7.778010e-30  1.319724e-27   Mybl2   1925.492840   1962.317688
# 287   1.065410e-17  5.962964e-16   Klf15    198.762606    198.477088
# 400   3.777553e-15  1.518463e-13  Thrap3  10425.339663  10938.409434
# 1064  7.466929e-09  1.130135e-07   Tex15    224.634563    267.555544
# 1239  5.712726e-08  7.426083e-07   Ewsr1  13547.773776  12672.789006
#
#       37_degrees.2    32_degrees  32_degrees.1  32_degrees.2  32_degrees.3
# 94     1959.319722   3231.128288   2953.678571   3356.427554   3202.788880
# 287     227.949572    461.196829    406.413795    473.410991    525.157008
# 400   11052.282334  13756.521675  13738.502172  14347.826532  13514.267291
# 1064    244.835654    427.383394    414.389986    426.646040    367.099904
# 1239  13453.752302  15696.576688  15431.096024  15865.480170  15365.298910

# %%
selected_df = selected_df[['gene', 'log2FoldChange', 'pvalue']]
selected_df.reset_index(drop= True, inplace = True)
selected_df.head()
# Out:
#      gene  log2FoldChange        pvalue
# 0   Mybl2        0.709024  7.778010e-30
# 1   Klf15        1.162393  1.065410e-17
# 2  Thrap3        0.356678  3.777553e-15
# 3   Tex15        0.731618  7.466929e-09
# 4   Ewsr1        0.237480  5.712726e-08

# %%
heatmap_df = selected_df[['gene','log2FoldChange']]
heatmap_df.set_index('gene', inplace= True)

plt.subplots(figsize=(17,2))
plt.tight_layout()
seaborn.heatmap(heatmap_df.T, annot=False, cmap="bwr", linewidths=.5, center=0, vmin=-1.5, vmax=1.5,
               cbar_kws={'label': 'log2(FC)'})
plt.title('Expression difference between 32 and 37°C \n of the Smyd5-bound genes')
title_file = 'Heatmap_mNPC'
plt.savefig(file_directory+'3) output/'+title_file+'.svg')
