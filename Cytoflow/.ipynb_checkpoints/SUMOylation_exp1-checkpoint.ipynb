# %%
import numpy, seaborn, pandas
import scipy.stats as stats
from scipy.stats import gaussian_kde
import matplotlib, matplotlib.pyplot as plt

import re #to search

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width: 90% !important; }</style>"))
# Out:
# <style>.container { width: 90% !important; }</style>

# %%
file_directory = "/Users/kja11/OneDrive - Menntaský (1)/Mild_Hypothermia_project/in_silico/Python/"

input_path = "1) input/flow_cytometry/"
output_path = "3) output/flow_cytometry/"

# %% [markdown]
# # Data download and modifications

# %%
experiment = 'sumolylation experiment n°1'

# %% [markdown]
# ## Meta and statitics data

# %%
# Meta data, important for sample_name
df_meta = pandas.read_csv(file_directory + input_path + 'sumolylation_exp1_flowjo_table.csv', sep = ',')

# Interested in name and Mode (the most frequently occurring value)
df_meta = df_meta.rename(columns = {'Unnamed: 0' : 'sample_name',
                                    'HEK293/Single Cells | Geometric Mean (FL3-A :: mCherry-A)' : 'gMFI'})
print(df_meta.shape, '\n')
df_meta.tail(5)
# Out:
# (30, 4)
#                            sample_name   gMFI  \
# 25      37 SP1 ctl_Data Source - 1.fcs   7658
# 26  37 SP1 sumo1a _Data Source - 1.fcs   8856
# 27       Unstained_Data Source - 1.fcs    381
# 28                                Mean  11077
# 29                                  SD  11324
#
#     HEK293/Single Cells | Mode (FL3-A :: mCherry-A)  \
# 25                                          11342.0
# 26                                          17077.0
# 27                                            455.0
# 28                                          24849.0
# 29                                          29903.0
#
#     HEK293/Single Cells | Count
# 25                        80071
# 26                        73848
# 27                        77140
# 28                        43691
# 29                        28448

# %%
# remove the last rows
df_meta = df_meta[(df_meta['sample_name'] != 'Mean') & (df_meta['sample_name'] != 'SD')]
df_meta.tail()
# Out:
#                            sample_name  gMFI  \
# 23   32 sp1 sumo2a_Data Source - 1.fcs  9339
# 24   37 sp1 sumo2a_Data Source - 1.fcs  7915
# 25      37 SP1 ctl_Data Source - 1.fcs  7658
# 26  37 SP1 sumo1a _Data Source - 1.fcs  8856
# 27       Unstained_Data Source - 1.fcs   381
#
#     HEK293/Single Cells | Mode (FL3-A :: mCherry-A)  \
# 23                                          14330.0
# 24                                          14330.0
# 25                                          11342.0
# 26                                          17077.0
# 27                                            455.0
#
#     HEK293/Single Cells | Count
# 23                        87745
# 24                        77831
# 25                        80071
# 26                        73848
# 27                        77140

# %%
# Have to rename the samples to have clear labelling  
sample_name = df_meta.sample_name

# select the three meta info
df_meta['Temperature'] = sample_name.apply(lambda x: re.search(r'\b(32|37)\b', x).group()
                                           if re.search(r'\b(32|37)\b', x) 
                                           else None)

df_meta['mhi-target'] = sample_name.apply(lambda x: re.search(r'(rbm3|sp1|cirbp)', x, re.IGNORECASE).group().lower()
                                           if re.search(r'(rbm3|sp1|cirbp)', x, re.IGNORECASE) 
                                           else None)

df_meta['condition'] = sample_name.apply(lambda x: re.search(r'(Unstained|ctl|sumo1a|sumo1b|sumo2a|sumo2b)', x, re.IGNORECASE).group()
                                          if re.search(r'(Unstained|ctl|sumo1a|sumo1b|sumo2a|sumo2b)', x, re.IGNORECASE) 
                                          else None)
df_meta
# Out:
#                                    sample_name   gMFI  \
# 0           32 rbm3 sumo1a_Data Source - 1.fcs   2913
# 1             32 cirbp ctl_Data Source - 1.fcs  19695
# 2           32 rbm3 sumo2b_Data Source - 1.fcs   2918
# 3           37 rbm3 sumo2b_Data Source - 1.fcs   1982
# 4      37 cirbp sumo2a - 1_Data Source - 1.fcs  22128
# 5            37 sp1 sumo2b_Data Source - 1.fcs   5254
# 6   32 sumo2b probably sp1_Data Source - 1.fcs   3413
# 7              37 rbm3 ctl_Data Source - 1.fcs   2232
# 8          32 cirbp sumo2b_Data Source - 1.fcs  32953
# 9           37 rbm3 sumo2a_Data Source - 1.fcs   1523
# 10    37 cirbp sumo1a  - 3_Data Source - 1.fcs  34520
# 11          37 rbm3 sumo1a_Data Source - 1.fcs    902
# 12       37 cirbp ctl  - 2_Data Source - 1.fcs  28059
# 13              32 sp1 ctl_Data Source - 1.fcs   5553
# 14           32 SP1 sumo1a_Data Source - 1.fcs  11673
# 15      32 rbm3 sumo2a bis_Data Source - 1.fcs   4115
# 16          37 rbm3 sumo1b_Data Source - 1.fcs   1940
# 17           32 sp1 sumo1b_Data Source - 1.fcs   7340
# 18         37 cirbp sumo1b_Data Source - 1.fcs  21587
# 19             32 rbm3 ctl_Data Source - 1.fcs   1594
# 20         32 cirbp sumo1a_Data Source - 1.fcs  31480
# 21        32 cirbp sumo1b _Data Source - 1.fcs  29890
# 22      32 rbm3 sumo2a - 1_Data Source - 1.fcs   2354
# 23           32 sp1 sumo2a_Data Source - 1.fcs   9339
# 24           37 sp1 sumo2a_Data Source - 1.fcs   7915
# 25              37 SP1 ctl_Data Source - 1.fcs   7658
# 26          37 SP1 sumo1a _Data Source - 1.fcs   8856
# 27               Unstained_Data Source - 1.fcs    381
#
#     HEK293/Single Cells | Mode (FL3-A :: mCherry-A)  \
# 0                                           3323.00
# 1                                          69470.00
# 2                                           3134.00
# 3                                           2630.00
# 4                                          78087.00
# 5                                              3.16
# 6                                           2340.00
# 7                                           3323.00
# 8                                          69470.00
# 9                                           2630.00
# 10                                         69470.00
# 11                                             3.16
# 12                                         58294.00
# 13                                         12749.00
# 14                                         19196.00
# 15                                          3960.00
# 16                                          2630.00
# 17                                         13516.00
# 18                                         65525.00
# 19                                          2788.00
# 20                                         73652.00
# 21                                         78087.00
# 22                                          3960.00
# 23                                         14330.00
# 24                                         14330.00
# 25                                         11342.00
# 26                                         17077.00
# 27                                           455.00
#
#     HEK293/Single Cells | Count Temperature mhi-target  condition
# 0                          1053          32       rbm3     sumo1a
# 1                          2330          32      cirbp        ctl
# 2                          6566          32       rbm3     sumo2b
# 3                          7420          37       rbm3     sumo2b
# 4                         10021          37      cirbp     sumo2a
# 5                          9468          37        sp1     sumo2b
# 6                         12512          32        sp1     sumo2b
# 7                         21696          37       rbm3        ctl
# 8                         27174          32      cirbp     sumo2b
# 9                         31193          37       rbm3     sumo2a
# 10                        37949          37      cirbp     sumo1a
# 11                        27555          37       rbm3     sumo1a
# 12                        37357          37      cirbp        ctl
# 13                        45816          32        sp1        ctl
# 14                        44203          32        sp1     sumo1a
# 15                        46979          32       rbm3     sumo2a
# 16                        48120          37       rbm3     sumo1b
# 17                        58668          32        sp1     sumo1b
# 18                        44208          37      cirbp     sumo1b
# 19                        73987          32       rbm3        ctl
# 20                        82913          32      cirbp     sumo1a
# 21                        75115          32      cirbp     sumo1b
# 22                        74409          32       rbm3     sumo2a
# 23                        87745          32        sp1     sumo2a
# 24                        77831          37        sp1     sumo2a
# 25                        80071          37        sp1        ctl
# 26                        73848          37        sp1     sumo1a
# 27                        77140        None       None  Unstained

# %%
# to not have None and create a clean label
df_meta.loc[df_meta['condition'] == 'Unstained', ['mhi-target', 'Temperature']] = ['HEK293', 'control']

label_serie = df_meta[['mhi-target', 'condition', 'Temperature']].agg('_'.join, axis=1)
df_meta.insert(0, "label", label_serie)
df_meta.head()
# Out:
#              label                              sample_name   gMFI  \
# 0   rbm3_sumo1a_32       32 rbm3 sumo1a_Data Source - 1.fcs   2913
# 1     cirbp_ctl_32         32 cirbp ctl_Data Source - 1.fcs  19695
# 2   rbm3_sumo2b_32       32 rbm3 sumo2b_Data Source - 1.fcs   2918
# 3   rbm3_sumo2b_37       37 rbm3 sumo2b_Data Source - 1.fcs   1982
# 4  cirbp_sumo2a_37  37 cirbp sumo2a - 1_Data Source - 1.fcs  22128
#
#    HEK293/Single Cells | Mode (FL3-A :: mCherry-A)  \
# 0                                           3323.0
# 1                                          69470.0
# 2                                           3134.0
# 3                                           2630.0
# 4                                          78087.0
#
#    HEK293/Single Cells | Count Temperature mhi-target condition
# 0                         1053          32       rbm3    sumo1a
# 1                         2330          32      cirbp       ctl
# 2                         6566          32       rbm3    sumo2b
# 3                         7420          37       rbm3    sumo2b
# 4                        10021          37      cirbp    sumo2a

# %%
# Calculate Geometric mean fluorescence ratio
gMFI_control = df_meta[df_meta.label == 'HEK293_Unstained_control']['gMFI'].iloc[0]
df_meta = df_meta.assign(gMFI_ratio = (df_meta.gMFI/gMFI_control))

# Add SampleID to merge with the flow data
df_meta['SampleID'] = ''
df_meta['SampleID'] = range(1, len(df_meta) + 1)
df_meta = df_meta[['label','SampleID', 'gMFI_ratio']]
df_meta.head()
# Out:
#              label  SampleID  gMFI_ratio
# 0   rbm3_sumo1a_32         1    7.645669
# 1     cirbp_ctl_32         2   51.692913
# 2   rbm3_sumo2b_32         3    7.658793
# 3   rbm3_sumo2b_37         4    5.202100
# 4  cirbp_sumo2a_37         5   58.078740

# %% [markdown]
# ## Flow data

# %%
#data Flow Cytometry
df = pandas.read_csv(file_directory + input_path + 'sumolylation_exp1_flowjo.csv', sep = ',')

print(df.shape, '\n')
df
# Out:
# (1223347, 9)
#             FSC-A     FSC-H  FSC-W     SSC-A     SSC-H  SSC-W  mCherry-A  \
# 0        500774.0  202854.0    351  308716.0  127844.0    351  9771.2800
# 1        134982.0   85226.4    193   61446.3   39878.7    193   644.2860
# 2        185267.0   84355.0    225  429233.0  177607.0    225  1422.4800
# 3        309600.0  135286.0    316  278182.0  121629.0    316  3163.8800
# 4         91433.2   69409.8    148  114661.0   66627.7    148    81.5459
# ...           ...       ...    ...       ...       ...    ...        ...
# 1223342  145417.0   78644.2    193  300458.0  149116.0    193   462.3050
# 1223343   91904.8   68074.7    149  171285.0  127845.0    149   380.1540
# 1223344  225192.0  109237.0    250  397840.0  157857.0    250   829.4830
# 1223345  184162.0   82849.8    232  192190.0  103042.0    232   242.6620
# 1223346  256521.0  107551.0    283  347406.0  173865.0    283   591.6580
#
#                TIME  SampleID
# 0          0.000000         1
# 1          0.112331         1
# 2          0.139086         1
# 3          0.165337         1
# 4          0.231497         1
# ...             ...       ...
# 1223342  349.823000        28
# 1223343  349.826000        28
# 1223344  349.829000        28
# 1223345  349.830000        28
# 1223346  349.835000        28
#
# [1223347 rows x 9 columns]

# %%
print(f'Amount of SampleID: {df.SampleID.max()-1}')
print(f'Amount of meta-info label: {len(df_meta.label.unique())}')
# Out:
# Amount of SampleID: 27
# Amount of meta-info label: 27

# %% [markdown]
# ## Merge

# %%
# merge 
df = df_meta.merge(df)
df = df.drop(['SampleID', 'TIME', 'gMFI_ratio'], axis=1)
df
# Out:
#                             label     FSC-A     FSC-H  FSC-W     SSC-A  \
# 0                  rbm3_sumo1a_32  500774.0  202854.0    351  308716.0
# 1                  rbm3_sumo1a_32  134982.0   85226.4    193   61446.3
# 2                  rbm3_sumo1a_32  185267.0   84355.0    225  429233.0
# 3                  rbm3_sumo1a_32  309600.0  135286.0    316  278182.0
# 4                  rbm3_sumo1a_32   91433.2   69409.8    148  114661.0
# ...                           ...       ...       ...    ...       ...
# 1223342  HEK293_Unstained_control  145417.0   78644.2    193  300458.0
# 1223343  HEK293_Unstained_control   91904.8   68074.7    149  171285.0
# 1223344  HEK293_Unstained_control  225192.0  109237.0    250  397840.0
# 1223345  HEK293_Unstained_control  184162.0   82849.8    232  192190.0
# 1223346  HEK293_Unstained_control  256521.0  107551.0    283  347406.0
#
#             SSC-H  SSC-W  mCherry-A
# 0        127844.0    351  9771.2800
# 1         39878.7    193   644.2860
# 2        177607.0    225  1422.4800
# 3        121629.0    316  3163.8800
# 4         66627.7    148    81.5459
# ...           ...    ...        ...
# 1223342  149116.0    193   462.3050
# 1223343  127845.0    149   380.1540
# 1223344  157857.0    250   829.4830
# 1223345  103042.0    232   242.6620
# 1223346  173865.0    283   591.6580
#
# [1223347 rows x 8 columns]

# %%
df.label.unique()
# Out:
# array(['rbm3_sumo1a_32', 'cirbp_ctl_32', 'rbm3_sumo2b_32',
#        'rbm3_sumo2b_37', 'cirbp_sumo2a_37', 'sp1_sumo2b_37',
#        'sp1_sumo2b_32', 'rbm3_ctl_37', 'cirbp_sumo2b_32',
#        'rbm3_sumo2a_37', 'cirbp_sumo1a_37', 'rbm3_sumo1a_37',
#        'cirbp_ctl_37', 'sp1_ctl_32', 'sp1_sumo1a_32', 'rbm3_sumo2a_32',
#        'rbm3_sumo1b_37', 'sp1_sumo1b_32', 'cirbp_sumo1b_37',
#        'rbm3_ctl_32', 'cirbp_sumo1a_32', 'cirbp_sumo1b_32',
#        'sp1_sumo2a_32', 'sp1_sumo2a_37', 'sp1_ctl_37', 'sp1_sumo1a_37',
#        'HEK293_Unstained_control'], dtype=object)

# %% [markdown]
# # Graphics

# %%
# Define a function to process data and calculate KDE
def process_and_plot(sample_data, color, label):
    data = sample_data['mCherry-A'].apply(numpy.log10)
    data = data[numpy.isfinite(data)] #not have infinte or nan
    
    # perform Kernel Density Estimation
    kde = gaussian_kde(data)
    x = numpy.linspace(min(data), max(data), 1000)
    y = kde(x)
    
    # normalize to have y from 0 to 100
    peak_y = numpy.max(y)
    normalized_y = (y / peak_y) * 100
    
    # find Mode
    mode_index = numpy.argmax(y)
    mode_value = x[mode_index]

    # Plot 
    plt.plot(x, normalized_y, color=color, alpha=0.7, label=f'{label}; {MHI.upper()}-MHI si{condition.upper()}' if label.startswith('3') else f'{label}')
    plt.fill_between(x, normalized_y, color=color, alpha=0.3) # fill the curve
    plt.axvline(mode_value, color=color, linestyle='--') # add vertical line 
    plt.xlim(0, 6.5)
    
    return mode_value # return to see if one sample is missing

# %%
# Define parameters
unstained_control = 'HEK293_Unstained_control'
temperatures = [32, 37]
MHIs = ['rbm3', 'sp1', 'cirbp']
conditions = ['ctl', 'sumo1a', 'sumo1b', 'sumo2a', 'sumo2b']

# Loop over MHIs and conditions
missing_samples_l = []

for MHI in MHIs:
    for condition in conditions:
        fig = plt.figure(figsize=(10, 6))

        # Plot the Unstained control
        sample_control = df[df['label'] == unstained_control]
        process_and_plot(sample_control, 'gray', 'Unstained Control')
        
        mode_32 = None
        mode_37 = None
        missing_sample = False
        
        for temp, color in zip(temperatures, ['blue', 'red']):
            label = f'{MHI}_{condition}_{temp}'
            sample = df[df['label'] == label]
            
            # if one sample is missing, stop
            if sample.empty:
                missing_samples_l.append(label)
                missing_sample = True
                break 
            
            # save mode value to calculate % later
            mode_value = process_and_plot(sample, color, f'{temp}°C')
            if temp == 32:
                mode_32 = mode_value
            elif temp == 37:
                mode_37 = mode_value
                
        # Close the plot if any sample is missing        
        if missing_sample:
            plt.close(fig)  
            continue
                
        # Calculate and annotate percentage change if both modes are available
        if mode_32 is not None and mode_37 is not None:
            percent_change = ((mode_32 - mode_37) / mode_37) * 100
            plt.text(mode_32 + 0.1, 100, f'{percent_change:+.2f}%', color='blue', fontsize=10)

        # Add labels and legend
        plt.xlabel('Log10(mCherry-A Intensity)')
        plt.ylabel('Normalized Density')
        plt.title(f'KDE Plot for {experiment}')
        plt.legend(loc='upper left')

        # Save the graph
        filename = f'{MHI}_{condition}_KDE_plot.png'
#         plt.savefig(filename)
        plt.show()
        plt.close(fig)

#print missing samples   
print(f'Missing samples are: {missing_samples_l}')
# Out:
# Missing samples are: ['rbm3_sumo1b_32', 'sp1_sumo1b_37', 'cirbp_sumo2a_32', 'cirbp_sumo2b_37']
