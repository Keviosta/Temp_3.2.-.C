# %%
import pandas

# %%
file_directory = "/Users/kja11/OneDrive - Menntaský/PostDoc_Hypothermia/in_silico/Python/"

# %%
# %%time
#data mouse_NPC
df = pandas.read_csv(file_directory+'1) input/PAAD_correlations1.csv',
                               sep = ',')
print(df.shape)
df
# Out:
# (157, 42)
# CPU times: total: 0 ns
# Wall time: 8.05 ms
#         TCGA_barcode     ASPC1     BXPC3    CAPAN1    CAPAN2    CFPAC1  \
# 0    TCGA-2J-AAB1-01  0.638181  0.602381  0.676095  0.629835  0.657429
# 1    TCGA-2J-AAB4-01  0.622214  0.594672  0.681799  0.639114  0.672480
# 2    TCGA-2J-AAB6-01  0.605073  0.666621  0.665001  0.664675  0.689835
# 3    TCGA-2J-AAB8-01  0.683364  0.653552  0.721422  0.689708  0.707624
# 4    TCGA-2J-AAB9-01  0.589819  0.584545  0.644864  0.616627  0.653848
# ..               ...       ...       ...       ...       ...       ...
# 152  TCGA-XN-A8T3-01  0.593749  0.579478  0.653538  0.638402  0.662858
# 153  TCGA-XN-A8T5-01  0.557886  0.555539  0.599022  0.583373  0.611130
# 154  TCGA-YB-A89D-01  0.611887  0.590381  0.649633  0.614668  0.643497
# 155  TCGA-YH-A8SY-01  0.658607  0.694241  0.713109  0.696141  0.714445
# 156  TCGA-YY-A8LH-01  0.692644  0.658127  0.733403  0.687509  0.707612
#
# ...

# %%
#save to csv
path = 'dataframes_for_input/'

df.to_csv(file_directory+'1) input/ta_mere.tsv',sep = "\t")

# %%
PAAD_correlations1.csv
