# %%
import pandas, scipy, numpy, seaborn
import matplotlib, matplotlib.pyplot as plt
from matplotlib.patches import Patch
from scipy.stats import pearsonr

# %%
matplotlib.rcParams.update({'font.size':20, 'xtick.labelsize':20, 'ytick.labelsize':20, 
                            'axes.grid' : True, 'grid.alpha': 0.5, 'grid.linestyle' : ':',
                            'figure.figsize':(8, 5), 'svg.fonttype' : 'none'})

# %%
file_directory = "/Users/kja11/OneDrive - Menntaský (1)/Mild_Hypothermia_project/in_silico/Python/"

# %%
path = "1) input/RNAseq/"

# %% [markdown]
# # II] Data Download

# %% [markdown]
# ## a. Expression File

# %%
#data all_counts_filtered
df_count = pandas.read_csv(file_directory+path+ 'transcript_HEK293_temp_all_counts_unfiltered.tsv',
                     sep = '\t')
print(df_count.shape)
df_count.head()
# Out:
# (135603, 9)
#            gene_id gene_name       feature_id  s37rep2  s32rep3  s37rep1  \
# 0  ENSG00000198034     RPS4X  ENST00000316084   232646   199874   190685
# 1  ENSG00000142937      RPS8  ENST00000396651   191357   163277   156765
# 2  ENSG00000182774     RPS17  ENST00000647841   188996   163258   157911
# 3  ENSG00000229117     RPL41  ENST00000546591   182501   170503   142081
# 4  ENSG00000142937      RPS8  ENST00000485390   182336   155347   148909
#
#    s37rep3  s32rep1  s32rep2
# 0   196125   160799   177622
# 1   160123   133777   150626
# 2   153051   133896   156007
# 3   168055   126151   146154
# 4   154214   126332   142296

# %%
# Remove the non expressed transcripts (less than 10 counts)
full_leng = len(df_count)
df_count = df_count[df_count.max(axis=1) >= 10]

filtr_leng = len(df_count)
dropped_transcripts = full_leng - filtr_leng

print(f'On {full_leng}, {dropped_transcripts} transcripts do not exceed 10 counts')

df_count
# Out:
# On 135603, 68143 transcripts do not exceed 10 counts
# C:\Users\kja11\AppData\Local\Temp\ipykernel_27364\2379892154.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_count = df_count[df_count.max(axis=1) >= 10]
#                 gene_id gene_name       feature_id  s37rep2  s32rep3  s37rep1  \
# 0       ENSG00000198034     RPS4X  ENST00000316084   232646   199874   190685
# 1       ENSG00000142937      RPS8  ENST00000396651   191357   163277   156765
# 2       ENSG00000182774     RPS17  ENST00000647841   188996   163258   157911
# 3       ENSG00000229117     RPL41  ENST00000546591   182501   170503   142081
# 4       ENSG00000142937      RPS8  ENST00000485390   182336   155347   148909
# ...                 ...       ...              ...      ...      ...      ...
# 121734  ENSG00000185513   L3MBTL1  ENST00000648570        0        0        1
# 125156  ENSG00000079337   RAPGEF3  ENST00000395360        0        0        0
# 125157  ENSG00000079337   RAPGEF3  ENST00000479866        0        0        0
# 125332  ENSG00000134900      TPP2  ENST00000698386        0        0        0
# 127643  ENSG00000171388      APLN  ENST00000429967        0        0        0
#
#         s37rep3  s32rep1  s32rep2
# 0        196125   160799   177622
# 1        160123   133777   150626
# 2        153051   133896   156007
# 3        168055   126151   146154
# 4        154214   126332   142296
# ...         ...      ...      ...
# 121734       16        0        1
# 125156       24        0        0
# 125157       12        0        1
# 125332        4       10        4
# 127643        1       11        1
#
# [67460 rows x 9 columns]

# %%
# calculate mean
df_count = df_count.assign(mean_32C = (df_count[['s37rep1', 's37rep2', 's37rep3']].mean(axis=1).round(0)),
                           mean_37C = (df_count[['s32rep1', 's32rep2', 's32rep3']].mean(axis=1).round(0))) 

df_count.rename(columns={df_count.columns[2]: 'transcript_id'},inplace=True)
df_count = df_count[['transcript_id','gene_name', 'mean_37C', 'mean_32C']]
print(len(df_count))
df_count.head()
# Out:
# 67460
#      transcript_id gene_name  mean_37C  mean_32C
# 0  ENST00000316084     RPS4X  179432.0  206485.0
# 1  ENST00000396651      RPS8  149227.0  169415.0
# 2  ENST00000647841     RPS17  151054.0  166653.0
# 3  ENST00000546591     RPL41  147603.0  164212.0
# 4  ENST00000485390      RPS8  141325.0  161820.0

# %% [markdown]
# ## b. Transcript information file

# %%
# %%time
#data DETseq HEK293 
df_length = pandas.read_csv(file_directory+path+ '20240216_mytranscripts.gtf',
                               sep = '\t', comment='#', header=None)
print(df_length.shape)

df_length.columns = ["seqname", "source", "feature", "start", "end",
                  "score", "strand", "frame", "attribute"]
df_length.head()
# Out:
# <timed exec>:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
# (2704200, 9)
# CPU times: total: 5.45 s
# Wall time: 19.7 s
#   seqname  source      feature    start      end score strand frame  \
# 0       1  havana   transcript  3069168  3434342     .      +     .
# 1       1  havana         exon  3069168  3069296     .      +     .
# 2       1  havana          CDS  3069260  3069296     .      +     0
# 3       1  havana  start_codon  3069260  3069262     .      +     0
# 4       1  havana         exon  3186125  3186474     .      +     .
#
#                                            attribute
# 0  gene_id "ENSG00000142611"; gene_version "17"; ...
# 1  gene_id "ENSG00000142611"; gene_version "17"; ...
# 2  gene_id "ENSG00000142611"; gene_version "17"; ...
# 3  gene_id "ENSG00000142611"; gene_version "17"; ...
# 4  gene_id "ENSG00000142611"; gene_version "17"; ...

# %%
df_length.feature.value_counts()
# Out:
# exon               1249376
# CDS                 806427
# three_prime_utr     186267
# five_prime_utr      149587
# transcript          146122
# start_codon          84688
# stop_codon           81611
# Selenocysteine         122
# Name: feature, dtype: int64

# %%
# coding sequence (CDS) regions
df_length = df_length[df_length["feature"] == "CDS"]

#Group CDS entries by transcript ID
df_length['transcript_id'] = df_length['attribute'].str.extract(r'transcript_id "([^"]+)"')

# Sum up CDS lengths per transcript
df_length['cds_length'] = df_length['end'] - df_length['start'] + 1

# df_length.set_index('transcript_id', inplace = True, drop = True )
df_length = df_length[['transcript_id', 'cds_length']]
print(df_length.describe())
df_length
# Out:
# 806427
#           cds_length
# count  806427.000000
# mean      149.678710
# std       252.721004
# min         1.000000
# 25%        80.000000
# 50%       117.000000
# 75%       162.000000
# max     50033.000000
#            transcript_id  cds_length
# 2        ENST00000511072          37
# 5        ENST00000511072         350
# 7        ENST00000511072          51
# 9        ENST00000511072         138
# 11       ENST00000511072         103
# ...                  ...         ...
# 2704176  ENST00000707305         124
# 2704178  ENST00000707305          34
# 2704191  ENST00000631997         125
# 2704193  ENST00000631997         202
# 2704195  ENST00000631997         293
#
# [806427 rows x 2 columns]

# %%
df_length = df_length.groupby('transcript_id')['cds_length'].sum()
df_length = df_length.reset_index()
df_length
# Out:
#          transcript_id  cds_length
# 0      ENST00000000233         540
# 1      ENST00000000412         831
# 2      ENST00000000442        1269
# 3      ENST00000001008        1377
# 4      ENST00000001146        1536
# ...                ...         ...
# 94133  ENST00000711264         780
# 94134  ENST00000711265         537
# 94135  ENST00000711272        1434
# 94136  ENST00000711286        1563
# 94137  ENST00000711287        1026
#
# [94138 rows x 2 columns]

# %% [markdown]
# ## c. Annotated data

# %%
#data DEseq HEK293 
df_annotated = pandas.read_csv(file_directory+'1) input/RNAseq/from_output/DETranscripts_HEK293_temp_annotated.csv',
                               sep = ',')

print(len(df_annotated))
df_annotated = df_annotated.dropna(axis=0)
print(len(df_annotated))
df_annotated.head(2)
# Out:
# 67460
# 57574
#      transcript_id Gene name Transcript name          gene_id       Gene type  \
# 0  ENST00000316084     RPS4X       RPS4X-201  ENSG00000198034  protein_coding
# 1  ENST00000396651      RPS8        RPS8-202  ENSG00000142937  protein_coding
#
#   Transcript type                                   Gene description  \
# 0  protein_coding  ribosomal protein S4 X-linked [Source:HGNC Sym...
# 1  protein_coding  ribosomal protein S8 [Source:HGNC Symbol;Acc:H...
#
#         baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# 0  191445.754149         0.16671  0.237639  0.701529  0.482973  0.926364
# 1  158035.042472         0.18438  0.233656  0.789108  0.430049  0.912718

# %% [markdown]
# ## d. Merge

# %%
df = df_length.merge(df_count)

# calculate ratio - expression/size
df = df.assign(ratio_expsize_37C = df['mean_37C'] / df['cds_length'],
               ratio_expsize_32C = df['mean_32C'] / df['cds_length'])

df = df.merge(df_annotated)
df = df[['Transcript name','transcript_id', 'cds_length', 'Transcript type',
         'mean_37C', 'mean_32C', 'ratio_expsize_37C', 'ratio_expsize_32C', 'log2FoldChange','padj']]
df.head(2)
# Out:
#   Transcript name    transcript_id  cds_length Transcript type  mean_37C  \
# 0        ARF5-201  ENST00000000233         540  protein_coding    1189.0
# 1        M6PR-201  ENST00000000412         831  protein_coding     535.0
#
#    mean_32C  ratio_37C  ratio_32C  log2FoldChange      padj
# 0    1392.0   2.201852   2.577778        0.130411  0.947035
# 1     720.0   0.643803   0.866426       -0.052876  0.985027

# %% [markdown]
# ## Subsets

# %%
# select the significant one (differentially expressed)
df_signif = df[(df.padj < 0.05)]
print(f'{len(df_signif)} transcripts are significantly different between 37° and 32°C')

df_signif.head(2)
# Out:
# 495 transcripts are significantly different between 37° and 32°C
#    Transcript name    transcript_id  cds_length Transcript type  mean_37C  \
# 24      RHBDD2-201  ENST00000006777        1092  protein_coding     487.0
# 44      HIVEP2-201  ENST00000012134        7338  protein_coding      12.0
#
#     mean_32C  ratio_37C  ratio_32C  log2FoldChange      padj
# 24     347.0   0.445971   0.317766        0.831807  0.038757
# 44      49.0   0.001635   0.006678       -1.709714  0.020649

# %%
df_sign_up = df_signif[df_signif['log2FoldChange'] > 0]
df_sign_down = df_signif[df_signif['log2FoldChange'] < 0]

# %%
df_signif = df_signif.assign(effect=numpy.where(df_signif['log2FoldChange'] > 0, 'Up regul.', 'Down regul.'))
df_signif.head()
# Out:
#     Transcript name    transcript_id  cds_length Transcript type  mean_37C  \
# 24       RHBDD2-201  ENST00000006777        1092  protein_coding     487.0
# 44       HIVEP2-201  ENST00000012134        7338  protein_coding      12.0
# 173      ZNF222-201  ENST00000187879        1353  protein_coding      27.0
# 217       SIRT4-201  ENST00000202967         942  protein_coding      16.0
# 245        G2E3-201  ENST00000206595        2118  protein_coding     112.0
#
#      mean_32C  ratio_37C  ratio_32C  log2FoldChange      padj       effect
# 24      347.0   0.445971   0.317766        0.831807  0.038757    Up regul.
# 44       49.0   0.001635   0.006678       -1.709714  0.020649  Down regul.
# 173       9.0   0.019956   0.006652        1.976981  0.018375    Up regul.
# 217      60.0   0.016985   0.063694       -1.562606  0.019853  Down regul.
# 245     313.0   0.052880   0.147781       -1.097677  0.015309  Down regul.

# %%
df_signif.effect.value_counts()
# Out:
# Up regul.      345
# Down regul.    150
# Name: effect, dtype: int64

# %% [markdown]
# # Methods

# %%
df_sign_up = df_signif[df_signif['log2FoldChange'] > 0]
df_sign_down = df_signif[df_signif['log2FoldChange'] < 0]

effects = df_sign_up, df_sign_down
colors = 'gold', 'blueviolet'

for i in range(len(effects)):
    effect = effects[i]
    color = colors[i]
    
    size = effect[['cds_length']].apply(numpy.log10)
    values = size.values.flatten()
    
    #plot
    seaborn.histplot(values,color=color, kde=True, alpha=0.2)
    legend_elements = [Patch(facecolor='gold', label = f'{len(df_sign_up)} Up regul. transcripts'),
                       Patch(facecolor='blueviolet', label = f'{len(df_sign_down)} Down regul. transcripts')]
    
    plt.legend(handles=legend_elements, loc='upper right', fontsize=12)
    plt.title('Distribution of the differentially\n expressed transcripts size at 32°C')
    plt.xlabel('log10 total coding sequence (CDS) size (bp)')
    plt.ylabel('Count')
