# %%
import pandas, scipy, numpy, seaborn
import matplotlib, matplotlib.pyplot as plt

# %%
matplotlib.rcParams.update({'font.size':20, 'xtick.labelsize':20, 'ytick.labelsize':20, 
                            'axes.grid' : True, 'grid.alpha': 0.5, 'grid.linestyle' : ':',
                            'figure.figsize':(8, 5), 'svg.fonttype' : 'none'})

# %%
file_directory = "/Users/kja11/OneDrive - Menntaský/PostDoc_Hypothermia/in_silico/Python/"

# %% [markdown]
# # II] Data Download

# %%
#data DETseq HEK293 
df = pandas.read_csv(file_directory+'1) input/RNAseq/from_output/DETranscripts_HEK293_temp_annotated.csv',
                               sep = ',')
print(df.shape)
df.head()
# Out:
# (67460, 13)
#      transcript_id Gene name Transcript name          gene_id       Gene type  \
# 0  ENST00000316084     RPS4X       RPS4X-201  ENSG00000198034  protein_coding
# 1  ENST00000396651      RPS8        RPS8-202  ENSG00000142937  protein_coding
# 2  ENST00000647841     RPS17       RPS17-209  ENSG00000182774  protein_coding
# 3  ENST00000546591     RPL41       RPL41-204  ENSG00000229117  protein_coding
# 4  ENST00000485390      RPS8        RPS8-207  ENSG00000142937  protein_coding
#
#                   Transcript type  \
# 0                  protein_coding
# 1                  protein_coding
# 2                  protein_coding
# 3                  protein_coding
# 4  protein_coding_CDS_not_defined
#
#                                     Gene description       baseMean  \
# 0  ribosomal protein S4 X-linked [Source:HGNC Sym...  191445.754149
# 1  ribosomal protein S8 [Source:HGNC Symbol;Acc:H...  158035.042472
# 2  ribosomal protein S17 [Source:HGNC Symbol;Acc:...  157570.432134
# 3  ribosomal protein L41 [Source:HGNC Symbol;Acc:...  155707.749717
# 4  ribosomal protein S8 [Source:HGNC Symbol;Acc:H...  150346.682757
#
#    log2FoldChange     lfcSE      stat    pvalue      padj
# 0        0.166710  0.237639  0.701529  0.482973  0.926364
# 1        0.184380  0.233656  0.789108  0.430049  0.912718
# 2        0.227071  0.228550  0.993528  0.320453  0.880298
# 3        0.210090  0.256955  0.817615  0.413577  0.908170
# 4        0.171633  0.235535  0.728697  0.466187  0.922093

# %%
#open significant protein list 
with open(file_directory+'3) output/RNAseq/allsignif_transcripts_HEK293.txt') as f:
    allsignif_transcripts_HEK293 = f.read().splitlines()
    
print("significant protein list:", len(allsignif_transcripts_HEK293))

df_signif = df[df['Transcript name'].isin(allsignif_transcripts_HEK293)]
len(df_signif)
# Out:
# significant protein list: 695
# 694

# %% [markdown]
# ## Questions ?
# 1- How look like the volcano plot of all the transcripts?
#
# 2- The same but based on the transcripts type?
#
# 3- Do we confirm that we have lower protein coding transcripts at 32°?
#
# 4- What are the highest differentially expressed transcripts?
#
# 5- Where are the DEG in the in the DEtranscripts ?
#
# 6- Where are RBM3, CIRBP and RTN3?
#
# 7- How genes with loss of H3K36me3 at 32°C expresse their protoding transcripts ?

# %% [markdown]
# # II] Methods

# %% [markdown]
# ## 1- How look like the volcano plot of all the transcripts?

# %%
df['Transcript type'].value_counts()
# Out:
# Transcript type
# protein_coding                        41549
# retained_intron                       10205
# nonsense_mediated_decay                9218
# protein_coding_CDS_not_defined         5283
# processed_pseudogene                    335
# lncRNA                                  334
# transcribed_unprocessed_pseudogene      255
# unprocessed_pseudogene                  107
# transcribed_processed_pseudogene         34
# non_stop_decay                           29
# TEC                                      22
# rRNA_pseudogene                          19
# transcribed_unitary_pseudogene           10
# protein_coding_LoF                        7
# IG_V_gene                                 1
# processed_transcript                      1
# Name: count, dtype: int64

# %%
#volcano plot
# Plot, after convertion  y to log10(pvalue)
plt.scatter(x=df['log2FoldChange'],y=df['padj'].apply(lambda x:-numpy.log10(x)),s=5)

# plt.legend(fontsize = '14')
plt.xlim(-7, 7)
plt.ylim(0, 41)
plt.xlabel("Log2.FoldChange")
plt.ylabel("adjp.value -log10")

# pvalue <0.05
plt.axhline(-numpy.log10(0.05),color="grey",linestyle="--")

# title_file = 'volcano_'
# plt.savefig(file_directory+'3) output/'+title_file+'.svg')

# %% [markdown]
# ## 2- The same but based on the transcripts type?

# %%
df_signif['Transcript type'].value_counts()
# Out:
# protein_coding                        430
# protein_coding_CDS_not_defined         99
# retained_intron                        82
# nonsense_mediated_decay                66
# transcribed_unprocessed_pseudogene      7
# unprocessed_pseudogene                  6
# lncRNA                                  5
# processed_pseudogene                    5
# non_stop_decay                          1
# transcribed_unitary_pseudogene          1
# Name: Transcript type, dtype: int64

# %%
# Top 15 rows
top_15 = df_signif.sort_values(by='padj', ascending=True).head(10)

seaborn.scatterplot(data=df_signif, x=df_signif['log2FoldChange'], 
                    y=df_signif['padj'].apply(lambda x:-numpy.log10(x)), 
                    s=20, edgecolor='none', hue="Transcript type")

# Annotate points on the plot with Symbol names
for index, row in top_15.iterrows():
    plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                fontsize = 10)

plt.legend(loc='upper right', bbox_to_anchor=(1.70, 1), fontsize='15')

plt.axhline(-numpy.log10(0.05),color="grey",linestyle="--")

plt.xlim(-7, 7)
plt.xlabel("Log2 FoldChange")
plt.ylabel("adjp.value -log10")

title_file = 'volcano_HEK_transcriptome_signif_pertype'
# plt.savefig(file_directory+'3) output/'+title_file+'.svg')

# %%
# check up what is what
df_signif.sort_values('padj', ascending = True).head(15)
# Out:
#                 Gene name Transcript name          gene_id       Gene type  \
# transcript_id
# ENST00000569263     CNOT1       CNOT1-217  ENSG00000125107  protein_coding
# ENST00000547157   NDUFA12     NDUFA12-204  ENSG00000184752  protein_coding
# ENST00000553521     SRSF5       SRSF5-203  ENSG00000100650  protein_coding
# ENST00000557154     SRSF5       SRSF5-217  ENSG00000100650  protein_coding
# ENST00000569020     CNOT1       CNOT1-215  ENSG00000125107  protein_coding
# ENST00000694867    NUP160      NUP160-213  ENSG00000030066  protein_coding
# ENST00000526870    NUP160      NUP160-203  ENSG00000030066  protein_coding
# ENST00000465471      SKA3        SKA3-205  ENSG00000165480  protein_coding
# ENST00000560495     ANXA2       ANXA2-234  ENSG00000182718  protein_coding
# ENST00000481219    SETDB1      SETDB1-210  ENSG00000143379  protein_coding
# ENST00000568158     CNOT1       CNOT1-213  ENSG00000125107  protein_coding
# ENST00000394366     SRSF5       SRSF5-201  ENSG00000100650  protein_coding
# ENST00000695605       AK2         AK2-223  ENSG00000004455  protein_coding
# ENST00000587935     PTRH2       PTRH2-205  ENSG00000141378  protein_coding
# ENST00000464794     TFDP1       TFDP1-204  ENSG00000198176  protein_coding
#
#                                 Transcript type  \
# transcript_id
# ENST00000569263  protein_coding_CDS_not_defined
# ENST00000547157                  protein_coding
# ENST00000553521                  protein_coding
# ENST00000557154                  protein_coding
# ENST00000569020                  protein_coding
# ENST00000694867                  protein_coding
# ENST00000526870                  protein_coding
# ENST00000465471         nonsense_mediated_decay
# ENST00000560495  protein_coding_CDS_not_defined
# ENST00000481219                 retained_intron
# ENST00000568158  protein_coding_CDS_not_defined
# ENST00000394366                  protein_coding
# ENST00000695605         nonsense_mediated_decay
# ENST00000587935  protein_coding_CDS_not_defined
# ENST00000464794  protein_coding_CDS_not_defined
#
#                                                   Gene description  \
# transcript_id
# ENST00000569263  CCR4-NOT transcription complex subunit 1 [Sour...
# ENST00000547157  NADH:ubiquinone oxidoreductase subunit A12 [So...
# ENST00000553521  serine and arginine rich splicing factor 5 [So...
# ENST00000557154  serine and arginine rich splicing factor 5 [So...
# ENST00000569020  CCR4-NOT transcription complex subunit 1 [Sour...
# ENST00000694867  nucleoporin 160 [Source:HGNC Symbol;Acc:HGNC:1...
# ENST00000526870  nucleoporin 160 [Source:HGNC Symbol;Acc:HGNC:1...
# ENST00000465471  spindle and kinetochore associated complex sub...
# ENST00000560495       annexin A2 [Source:HGNC Symbol;Acc:HGNC:537]
# ENST00000481219  SET domain bifurcated histone lysine methyltra...
# ENST00000568158  CCR4-NOT transcription complex subunit 1 [Sour...
# ENST00000394366  serine and arginine rich splicing factor 5 [So...
# ENST00000695605  adenylate kinase 2 [Source:HGNC Symbol;Acc:HGN...
# ENST00000587935  peptidyl-tRNA hydrolase 2 [Source:HGNC Symbol;...
# ENST00000464794  transcription factor Dp-1 [Source:HGNC Symbol;...
#
#                     baseMean  log2FoldChange     lfcSE       stat  \
# transcript_id
# ENST00000569263   315.814365        4.338181  0.301606  14.383589
# ENST00000547157   419.398074        3.411533  0.267534  12.751785
# ENST00000553521  2322.642416        2.335998  0.198832  11.748586
# ENST00000557154  2179.685527        2.322788  0.198650  11.692848
# ENST00000569020    82.112140        4.563910  0.428002  10.663288
# ENST00000694867   160.701219        2.810951  0.280511  10.020813
# ENST00000526870   162.744390        2.831842  0.282236  10.033591
# ENST00000465471   441.871689        2.587981  0.268368   9.643391
# ENST00000560495    89.766880        3.372558  0.362979   9.291319
# ENST00000481219    89.995944        3.253906  0.354251   9.185317
# ENST00000568158   144.590977        2.654139  0.303966   8.731686
# ENST00000394366  1364.170114        1.766621  0.202673   8.716626
# ENST00000695605    80.677036        2.852040  0.331576   8.601472
# ENST00000587935    59.147811        3.582812  0.440124   8.140460
# ENST00000464794   450.549815        1.861806  0.230652   8.071931
#
#                        pvalue          padj
# transcript_id
# ENST00000569263  6.560270e-47  3.824506e-42
# ENST00000547157  3.046869e-37  8.881318e-33
# ENST00000553521  7.181006e-32  1.395461e-27
# ENST00000557154  1.386568e-31  2.020853e-27
# ENST00000569020  1.511578e-26  1.762439e-22
# ENST00000694867  1.234826e-23  1.028399e-19
# ENST00000526870  1.084971e-23  1.028399e-19
# ENST00000465471  5.242684e-22  3.820475e-18
# ENST00000560495  1.523884e-20  9.871043e-17
# ENST00000481219  4.103178e-20  2.392071e-16
# ENST00000568158  2.509038e-18  1.329744e-14
# ENST00000394366  2.866157e-18  1.392427e-14
# ENST00000695605  7.870035e-18  3.529287e-14
# ENST00000587935  3.937777e-16  1.639746e-12
# ENST00000464794  6.919490e-16  2.689283e-12

# %% [markdown]
# ## 3- Do we confirm that we have lower protein coding transcripts at 32°?

# %%
df_protcoding = df[(df['Transcript type'] == 'protein_coding') | 
                        (df['Transcript type'] == 'protein_coding_CDS_not_defined')]
print(f'{len(df_protcoding)} protein coding transcripts')

downregu = len(df_protcoding[df_protcoding['log2FoldChange'] < 0])
upregu = len(df_protcoding[df_protcoding['log2FoldChange'] > 0])

print(f'{downregu} are downregulated at 32°')
print(f'{upregu} are upregulated at 32°')
# Out:
# 46871 protein coding transcripts
# 23773 are downregulated at 32°
# 23098 are upregulated at 32°

# %%
# Top 15 rows
top_15 = df_protcoding.sort_values(by='padj', ascending=True).head(15)

seaborn.scatterplot(data=df_protcoding, x=df_protcoding['log2FoldChange'], 
                    y=df_protcoding['padj'].apply(lambda x:-numpy.log10(x)), 
                    s=20, edgecolor='none', hue="Transcript type")

plt.legend(loc='upper right', bbox_to_anchor=(1.70, 1), fontsize='15')

# Annotate points on the plot with Symbol names
for index, row in top_15.iterrows():
    plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                fontsize = 10)
    
# pvalue <0.05
plt.axhline(-numpy.log10(0.05),color="grey",linestyle="--")

plt.ylim(0, 41)
plt.xlim(-7, 7)
plt.xlabel("Log2 FoldChange")
plt.ylabel("adjp.value -log10")

title_file = 'volcano_HEK_transcriptome_protein_coding_signif_pertype'
# plt.savefig(file_directory+'3) output/'+title_file+'.svg')

# %%
df_protcoding = df_signif[(df_signif['Transcript type'] == 'protein_coding') | 
                        (df_signif['Transcript type'] == 'protein_coding_CDS_not_defined')]
print(f'{len(df_protcoding)} protein coding transcripts')

downregu = len(df_protcoding[df_protcoding['log2FoldChange'] < 0])
upregu = len(df_protcoding[df_protcoding['log2FoldChange'] > 0])

print(f'{downregu} are downregulated at 32°')
print(f'{upregu} are upregulated at 32°')
# Out:
# 526 protein coding transcripts
# 133 are downregulated at 32°
# 393 are upregulated at 32°

# %% [markdown]
# ## 4- What are the highest differentially expressed transcripts?

# %%
df_signif.head(1)
# Out:
#        transcript_id Gene name Transcript name          gene_id  \
# 896  ENST00000295470   HNRNPDL     HNRNPDL-201  ENSG00000152795
#
#           Gene type Transcript type  \
# 896  protein_coding  protein_coding
#
#                                       Gene description     baseMean  \
# 896  heterogeneous nuclear ribonucleoprotein D like...  6861.896999
#
#      log2FoldChange     lfcSE      stat    pvalue      padj
# 896        0.906518  0.239715  3.781649  0.000156  0.019366

# %%
# Top 30 rows are reprensented in the heatmap
top_20neg = df_signif.sort_values(by='log2FoldChange', ascending=True).head(20)
top_20pos = df_signif.sort_values(by='log2FoldChange', ascending=False).head(20)

# Define a dictionary to map transcript types to colors
color_dict = {
    'protein_coding': 'blue',
    'retained_intron': 'orange',
    'transcribed_unprocessed_pseudogene': 'green',
    'nonsense_mediated_decay': 'purple',
    'protein_coding_CDS_not_defined': 'red'}

# Pos
seaborn.scatterplot(data=top_20pos, x='log2FoldChange', y=top_20pos['padj'].apply(lambda x:-numpy.log10(x)), 
                    hue='Transcript type', palette=color_dict, s=20, edgecolor='none')
# Annotate points on the plot with Symbol names
for index, row in top_20pos.iterrows():
    plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                fontsize = 10)
    
# Neg    
seaborn.scatterplot(data=top_20neg, x='log2FoldChange', y=top_20neg['padj'].apply(lambda x:-numpy.log10(x)), 
                    hue='Transcript type', palette=color_dict, s=20, edgecolor='none', legend=False)
# Annotate points on the plot with Symbol names
for index, row in top_20neg.iterrows():
    plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                fontsize = 10)
    
plt.legend(loc='upper right', bbox_to_anchor=(1.70, 1), fontsize='15')

plt.axhline(-numpy.log10(0.05),color="grey",linestyle="--")
plt.title('top 20 higher FC')
plt.xlim(-7.5, 7.5)
plt.ylim(0, 45)
plt.xlabel("Log2 FoldChange")
plt.ylabel("adjp.value -log10")

title_file = 'volcano_top_highest_FC_Transcripts_HEK293'
# plt.savefig(file_directory+'3) output/RNAseq/'+title_file+'.svg')

# %%
# Top 30 rows are reprensented in the heatmap
top_30 = df_signif.sort_values(by='padj', ascending=True).head(30)

seaborn.scatterplot(data=top_30, x=df_signif['log2FoldChange'], 
                    y=df_signif['padj'].apply(lambda x:-numpy.log10(x)), 
                    s=20, edgecolor='none', hue="Transcript type")

# Annotate points on the plot with Symbol names
for index, row in top_30.iterrows():
    plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                fontsize = 10)

plt.legend(loc='upper right', bbox_to_anchor=(1.70, 1), fontsize='15')

plt.axhline(-numpy.log10(0.05),color="grey",linestyle="--")
plt.xlim(-7, 7)
plt.ylim(0, 45)
plt.xlabel("Log2 FoldChange")
plt.ylabel("adjp.value -log10")

title_file = 'volcano_top_lowest_adjPval_Transcripts_HEK293'
plt.savefig(file_directory+'3) output/RNAseq/'+title_file+'.svg')

# %%
#select the interesting genes
df_hm = df_signif.sort_values(by='padj', ascending=True).head(30)

max_pval = df_hm['padj'].max()
print(f'highest adj-pvalue is {max_pval}')

df_hm = df_hm[['Transcript name', 'log2FoldChange']]
df_hm.set_index('Transcript name', drop = True, inplace= True)

print(f"max is {df_hm['log2FoldChange'].max()}, min is {df_hm['log2FoldChange'].min()}")
df_hm.head()
# Out:
# highest adj-pvalue is 2.6508916191396345e-09
# max is 4.563909853665846, min is 1.4545607221152226
#                  log2FoldChange
# Transcript name
# CNOT1-217              4.338181
# NDUFA12-204            3.411533
# SRSF5-203              2.335998
# SRSF5-217              2.322788
# CNOT1-215              4.563910

# %%
plt.subplots(figsize=(17,0.5))
seaborn.heatmap(df_hm.T, annot=False, cmap="bwr", linewidths=.5, center=0, vmin=0, vmax=5,
               cbar_kws={'label': 'log2FoldChange \n (32° vs 37°)', 'location' : 'top', 'orientation': 'horizontal',
                        'aspect': 50})

title_file = 'heatmap_HEK293_transcriptome'
# plt.savefig(file_directory+'3) output/'+title_file+'.svg')

# %%
#select the interesting genes
df_hm_details = df_signif.sort_values(by='padj', ascending=True).head(30)
represented_genes = df_hm_details['Gene name'].unique()
print(represented_genes)
# numpy.savetxt(file_directory+"3) output/top30_transcripts_genes_name_HEK293.txt", 
#               represented_genes, delimiter="\t", fmt="% s")

df_hm_details[['Gene name', 'Transcript name', 'Transcript type', 'Gene description']].head(30)
# Out:
# ['CNOT1' 'NDUFA12' 'SRSF5' 'NUP160' 'SKA3' 'ANXA2' 'SETDB1' 'AK2' 'PTRH2'
#  'TFDP1' 'RPP30' 'ABCD3' 'PCIF1' 'FANCB' 'SLC37A3' 'SNX5' 'SFT2D1' 'H3C6']
#                 Gene name Transcript name                 Transcript type  \
# transcript_id
# ENST00000569263     CNOT1       CNOT1-217  protein_coding_CDS_not_defined
# ENST00000547157   NDUFA12     NDUFA12-204                  protein_coding
# ENST00000553521     SRSF5       SRSF5-203                  protein_coding
# ENST00000557154     SRSF5       SRSF5-217                  protein_coding
# ENST00000569020     CNOT1       CNOT1-215                  protein_coding
# ENST00000694867    NUP160      NUP160-213                  protein_coding
# ENST00000526870    NUP160      NUP160-203                  protein_coding
# ENST00000465471      SKA3        SKA3-205         nonsense_mediated_decay
# ENST00000560495     ANXA2       ANXA2-234  protein_coding_CDS_not_defined
# ENST00000481219    SETDB1      SETDB1-210                 retained_intron
# ENST00000568158     CNOT1       CNOT1-213  protein_coding_CDS_not_defined
# ENST00000394366     SRSF5       SRSF5-201                  protein_coding
# ENST00000695605       AK2         AK2-223         nonsense_mediated_decay
# ENST00000587935     PTRH2       PTRH2-205  protein_coding_CDS_not_defined
# ENST00000464794     TFDP1       TFDP1-204  protein_coding_CDS_not_defined
# ENST00000556587     SRSF5       SRSF5-215  protein_coding_CDS_not_defined
# ENST00000470933     RPP30       RPP30-206  protein_coding_CDS_not_defined
# ENST00000315713     ABCD3       ABCD3-201                  protein_coding
# ENST00000616084     PCIF1       PCIF1-203  protein_coding_CDS_not_defined
# ENST00000696352     FANCB       FANCB-213         nonsense_mediated_decay
# ENST00000696351     FANCB       FANCB-212         nonsense_mediated_decay
# ENST00000696353     FANCB       FANCB-214                  protein_coding
# ENST00000452869     FANCB       FANCB-202                  protein_coding
# ENST00000554465     SRSF5       SRSF5-207                 retained_intron
# ENST00000495257   SLC37A3     SLC37A3-227  protein_coding_CDS_not_defined
# ENST00000673291       AK2         AK2-215                  protein_coding
# ENST00000606602      SNX5        SNX5-219                  protein_coding
# ENST00000400018      SKA3        SKA3-203                  protein_coding
# ENST00000478705    SFT2D1      SFT2D1-202  protein_coding_CDS_not_defined
# ENST00000634733      H3C6        H3C6-202                  protein_coding
#
#                                                   Gene description
# transcript_id
# ENST00000569263  CCR4-NOT transcription complex subunit 1 [Sour...
# ENST00000547157  NADH:ubiquinone oxidoreductase subunit A12 [So...
# ENST00000553521  serine and arginine rich splicing factor 5 [So...
# ENST00000557154  serine and arginine rich splicing factor 5 [So...
# ENST00000569020  CCR4-NOT transcription complex subunit 1 [Sour...
# ENST00000694867  nucleoporin 160 [Source:HGNC Symbol;Acc:HGNC:1...
# ENST00000526870  nucleoporin 160 [Source:HGNC Symbol;Acc:HGNC:1...
# ENST00000465471  spindle and kinetochore associated complex sub...
# ENST00000560495       annexin A2 [Source:HGNC Symbol;Acc:HGNC:537]
# ENST00000481219  SET domain bifurcated histone lysine methyltra...
# ENST00000568158  CCR4-NOT transcription complex subunit 1 [Sour...
# ENST00000394366  serine and arginine rich splicing factor 5 [So...
# ENST00000695605  adenylate kinase 2 [Source:HGNC Symbol;Acc:HGN...
# ENST00000587935  peptidyl-tRNA hydrolase 2 [Source:HGNC Symbol;...
# ENST00000464794  transcription factor Dp-1 [Source:HGNC Symbol;...
# ENST00000556587  serine and arginine rich splicing factor 5 [So...
# ENST00000470933  ribonuclease P/MRP subunit p30 [Source:HGNC Sy...
# ENST00000315713  ATP binding cassette subfamily D member 3 [Sou...
# ENST00000616084  phosphorylated CTD interacting factor 1 [Sourc...
# ENST00000696352  FA complementation group B [Source:HGNC Symbol...
# ENST00000696351  FA complementation group B [Source:HGNC Symbol...
# ENST00000696353  FA complementation group B [Source:HGNC Symbol...
# ENST00000452869  FA complementation group B [Source:HGNC Symbol...
# ENST00000554465  serine and arginine rich splicing factor 5 [So...
# ENST00000495257  solute carrier family 37 member 3 [Source:HGNC...
# ENST00000673291  adenylate kinase 2 [Source:HGNC Symbol;Acc:HGN...
# ENST00000606602  sorting nexin 5 [Source:HGNC Symbol;Acc:HGNC:1...
# ENST00000400018  spindle and kinetochore associated complex sub...
# ENST00000478705  SFT2 domain containing 1 [Source:HGNC Symbol;A...
# ENST00000634733  H3 clustered histone 6 [Source:HGNC Symbol;Acc...

# %% [markdown]
# ## 5- Where are the DEG in the in the DEtranscripts ?

# %%
top15_genes_HEK293 = file_directory+"3) output/top15_genes_HEK293.txt"
top5_negative_genes_HEK293 = file_directory+"3) output/top5_negative_genes_HEK293.txt"

with open(top15_genes_HEK293) as f:
    top15_genes_HEK293 = f.read().splitlines()
    
with open(top5_negative_genes_HEK293) as f:
    top5_negative_genes_HEK293 = f.read().splitlines()

# %%
DEG_list = top15_genes_HEK293 + top5_negative_genes_HEK293
len(DEG_list)
# Out:
# 20

# %%
df_onlyDEG = df[df['Gene name'].isin(DEG_list)]

seaborn.scatterplot(data=df_onlyDEG, 
                    x=df_onlyDEG['log2FoldChange'], 
                    y=df_onlyDEG['padj'].apply(lambda x:-numpy.log10(x)), 
                    s=20, edgecolor='none', color='white')

plt.scatter(x=[],y=[], marker="o", color='blue', label= 'downregulated genes')
plt.scatter(x=[],y=[], marker="o", color='red', label= 'upregulated genes')

# Annotate the DEGene
## upregulated one
for index, row in df_onlyDEG.iterrows():
    if row['Gene name'] in top15_genes_HEK293:
        plt.scatter(x=row['log2FoldChange'], y= -numpy.log10(row['padj']), 
                    s=20, color='red', edgecolor='black') 
        plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                     fontsize=7, color='k')
        
    elif row['Gene name'] in top5_negative_genes_HEK293:
        plt.scatter(x=row['log2FoldChange'], y= -numpy.log10(row['padj']), 
                    s=20, color='blue', edgecolor='black')  # Change 'red' to your desired color
        plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                     fontsize=7, color='k')


plt.legend(fontsize = '14')        
        
        
plt.axhline(-numpy.log10(0.05),color="grey",linestyle="--")

plt.title('Transcripts whose genes are DEG')
plt.xlim(-5, 5)
plt.xlabel("Log2 FoldChange")
plt.ylabel("adjp.value -log10")

title_file = 'volcano_HEK_transcriptome_onlyDEG'
# plt.savefig(file_directory+'3) output/'+title_file+'.svg')

# %%
#What genes are not represented
df['Gene name']
final_ = set(df_onlyDEG['Gene name'])
posDEG_ = set(top15_genes_HEK293)
negDEG_ = set(top5_negative_genes_HEK293)

print(f'The negative genes not in the transcriptome: {negDEG_.symmetric_difference(final_) & negDEG_}')
print(f'The positive genes not in the transcriptome: {posDEG_.symmetric_difference(final_) & posDEG_}')
# Out:
# The negative genes not in the transcriptome: {'FAM110A', 'TFEB', 'INSC'}
# The positive genes not in the transcriptome: {'HIST1H3E', 'FAM110D', 'AC011043.1', 'RP11-585F1.6'}

# %% [markdown]
# ## 6- Where are RBM3, CIRBP and RTN3?

# %%
# where are RBM3, CIRBP and RTN3? 
target_genes = ['RBM3', 'CIRBP', 'RTN3']

df_target = df[df['Gene name'].isin(target_genes)]

seaborn.scatterplot(data=df_target, 
                    x=df_target['log2FoldChange'], 
                    y=df_target['padj'].apply(lambda x:-numpy.log10(x)), 
                    s=20, edgecolor='none', color='white')

# Annotate the DEGene
## upregulated one
for index, row in df_target.iterrows():
    if row['Gene name'] == 'RBM3':
        plt.scatter(x=row['log2FoldChange'], y= -numpy.log10(row['padj']), 
                    s=20, color='red', edgecolor='black') 
        plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                     fontsize=8, color='k')
                
    elif row['Gene name'] in ['CIRBP', 'RTN3']:
        plt.scatter(x=row['log2FoldChange'], y= -numpy.log10(row['padj']), 
                    s=20, color='lightgrey', edgecolor='black')  # Change 'red' to your desired color
        plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                     fontsize=8, color='k')
        
plt.axhline(-numpy.log10(0.05),color="grey",linestyle="--")

plt.title('Transcripts whose genes are DEG')
plt.xlim(-5, 5)
plt.ylim(0, 26)
plt.xlim()
plt.xlabel("Log2 FoldChange")
plt.ylabel("adjp.value -log10")

title_file = 'volcano_HEK_transcriptome_targets'
# plt.savefig(file_directory+'3) output/'+title_file+'.svg')

# %%
len(df[df['Gene name'] == 'CIRBP'])
# Out:
# 27

# %% [markdown]
# ## 7- How genes with loss of H3K36me3 at 32°C expresse their protoding transcripts ?

# %%
#data HEK293 H3K36me3_topgenes (positive are gain of H3K36, negative is loss)
H3K36me3_topgenes = pandas.read_csv(file_directory+'1) input/from_output/HEK293_H3K36me3_topgenes.csv',
                     sep = ',')
print(len(H3K36me3_topgenes))

H3K36me3_topgenes = H3K36me3_topgenes.sort_values('Fold', ascending = True)
H3K36me3_topgenes.tail()
# Out:
# 112
#     SYMBOL      Fold       p.value
# 6   SREBF2  5.231205  8.312780e-08
# 4    THOC2  5.352110  6.949019e-08
# 2    TFB1M  5.448008  3.712064e-08
# 0  MIR4289  5.552725  2.461157e-08
# 1    MEX3C  5.621872  2.475970e-08

# %%
target_genes = H3K36me3_topgenes['SYMBOL'].unique()
df_target = df_protcoding[df_protcoding['Gene name'].isin(target_genes)]

print(f'{len(df_target)} protein coding transcripts are from gene with loss of H3K36')

print(H3K36me3_topgenes[H3K36me3_topgenes['SYMBOL'].isin(['SREK1', 'ASCC3'])],'\n','\n','\n', df_target)
# Out:
# 2 protein coding transcripts are from gene with loss of H3K36
#    SYMBOL      Fold   p.value
# 32  ASCC3 -4.368663  0.000001
# 79  SREK1 -3.912060  0.000010
#
#
#                  Gene name Transcript name          gene_id       Gene type  \
# transcript_id
# ENST00000334121     SREK1       SREK1-202  ENSG00000153914  protein_coding
# ENST00000369143     ASCC3       ASCC3-203  ENSG00000112249  protein_coding
#
#                 Transcript type  \
# transcript_id
# ENST00000334121  protein_coding
# ENST00000369143  protein_coding
#
#                                                   Gene description  \
# transcript_id
# ENST00000334121  splicing regulatory glutamic acid and lysine r...
# ENST00000369143  activating signal cointegrator 1 complex subun...
#
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# transcript_id
# ENST00000334121  282.039426       -0.934280  0.254036 -3.677743  0.000235
# ENST00000369143   91.060737        1.251637  0.299102  4.184649  0.000029
#
#                      padj
# transcript_id
# ENST00000334121  0.025834
# ENST00000369143  0.005883

# %%
df_target
# Out:
#                 Gene name Transcript name          gene_id       Gene type  \
# transcript_id
# ENST00000334121     SREK1       SREK1-202  ENSG00000153914  protein_coding
# ENST00000369143     ASCC3       ASCC3-203  ENSG00000112249  protein_coding
#
#                 Transcript type  \
# transcript_id
# ENST00000334121  protein_coding
# ENST00000369143  protein_coding
#
#                                                   Gene description  \
# transcript_id
# ENST00000334121  splicing regulatory glutamic acid and lysine r...
# ENST00000369143  activating signal cointegrator 1 complex subun...
#
#                    baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# transcript_id
# ENST00000334121  282.039426       -0.934280  0.254036 -3.677743  0.000235
# ENST00000369143   91.060737        1.251637  0.299102  4.184649  0.000029
#
#                      padj
# transcript_id
# ENST00000334121  0.025834
# ENST00000369143  0.005883

# %%
seaborn.scatterplot(data=df_target, 
                    x=df_target['log2FoldChange'], 
                    y=df_target['padj'].apply(lambda x:-numpy.log10(x)), 
                    s=20, edgecolor='none', color='k')

plt.scatter(x=[],y=[], marker="o", color='blue', label= 'genes with loss of H3K36me3')
plt.scatter(x=[],y=[], marker="o", color='red', label= 'genes with gain of H3K36me3')
# Annotate the DEGene
## upregulated one
for index, row in df_target.iterrows():
    if row['Gene name'] in set(H3K36me3_topgenes[H3K36me3_topgenes['Fold'] > 0]['SYMBOL']):
        plt.scatter(x=row['log2FoldChange'], y= -numpy.log10(row['padj']), 
                    s=20, color='red', edgecolor='black') 
        plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                     fontsize=8, color='red')
                
    elif row['Gene name'] in set(H3K36me3_topgenes[H3K36me3_topgenes['Fold'] < 0]['SYMBOL']):
        plt.scatter(x=row['log2FoldChange'], y= -numpy.log10(row['padj']), 
                    s=20, color='blue', edgecolor='black')  # Change 'red' to your desired color
        plt.annotate(row['Gene name'], (row['log2FoldChange'], -numpy.log10(row['padj'])),
                     fontsize=8, color='k')
        
plt.axhline(-numpy.log10(0.05),color="grey",linestyle="--")
plt.legend(fontsize= 14)
plt.title('Transcripts whose genes have \n altered H3K36me3 in HEK293')
plt.xlim(-5, 5)
plt.ylim(0, 26)
plt.xlim()
plt.xlabel("Log2 FoldChange")
plt.ylabel("adjp.value -log10")

title_file = 'volcano_HEK_transcriptome_targets'
# plt.savefig(file_directory+'3) output/'+title_file+'.svg')

# %%
target_genes = H3K36me3_topgenes['SYMBOL'].unique()
df_target = df[df['Gene name'].isin(target_genes)]
print(f'{len(df_target)} transcripts are from gene with loss of H3K36 (non prot_cod)')
print(f'the lower adj-pvalue found is {df_target.padj.round(2).min()}')
# Out:
# 617 transcripts are from gene with loss of H3K36 (non prot_cod)
# the lower adj-pvalue found is 0.01
