# %% [markdown]
# # I] Import and options

# %%
import pandas, numpy, seaborn, scipy, scipy.stats
import matplotlib, matplotlib.pyplot as plt

# %%
matplotlib.rcParams.update({'font.size':20, 'xtick.labelsize':20, 'ytick.labelsize':20, 
                            'axes.grid' : True, 'grid.alpha': 0.5, 'grid.linestyle' : ':',
                            'figure.figsize':(12, 8), 'svg.fonttype' : 'none'})

# %%
file_directory = "/Users/kja11/OneDrive - Menntaský/PostDoc_Hypothermia/in_silico/Python/"

# %%
path = "1) input/experiments/"

# %% [markdown]
# # II] DL data

# %%
df = pandas.read_csv(file_directory + path + 'degradation_blot_quantifs.csv', sep = ",")
df = df.assign(SMYD5_norm = df['Smyd5'] / df['Lamin B1'])
df.head()
# Out:
#   Condition  Temp           exp   Lamin B1      Smyd5  SMYD5_norm
# 0      DMSO    37  Experiment_1  12930.326   8487.669    0.656416
# 1    BAF_A1    37  Experiment_1  19584.912  10569.962    0.539699
# 2     MG132    37  Experiment_1  21507.447  10002.841    0.465087
# 3    BAF+MG    37  Experiment_1  16880.083   8665.426    0.513352
# 4      DMSO    32  Experiment_1  10758.134  12192.134    1.133294

# %%
    #graph
    seaborn.catplot(x="Condition", y="SMYD5_norm", hue="Temp", aspect= 1.2, kind="box", palette = 'mako',
                    data = df, boxprops={'lw':2, 'alpha' : 0.8}, medianprops={'lw':2}, whiskerprops={'lw':2}, 
                    showcaps=True, showfliers=False, legend=False)

    plt.tight_layout()
    plt.title('SMYD5 expression')
    plt.xticks(rotation=45, ha= 'right')
    plt.ylabel('relative prot. expr.')
    plt.xlabel('')
    plt.legend(loc='center right', fontsize=20, bbox_to_anchor=(1.55, 0.5))
# Out:
# C:\Users\kja11\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\kja11\AppData\Local\Temp\ipykernel_22880\1675660281.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
#graph
seaborn.catplot(x="Temp", y="SMYD5_norm", hue='Condition', aspect= 1.2, kind="box", palette = 'mako',
                    data = df, boxprops={'lw':2, 'alpha' : 0.8}, medianprops={'lw':2}, whiskerprops={'lw':2}, 
                    showcaps=True, showfliers=False, legend=False)

plt.tight_layout()
plt.title('SMYD5 expression at 6 hours ')
plt.xticks(rotation=45, ha= 'right')
plt.ylabel('relative prot. expr.')
plt.xlabel('')
plt.legend(loc='center right', fontsize=20, bbox_to_anchor=(1.55, 0.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #graph
# ----> 2 seaborn.catplot(x="Temp", y="SMYD5_norm", hue='Condition', aspect= 1.2, kind="box", palette = 'mako',
#       3                     data = df, boxprops={'lw':2, 'alpha' : 0.8}, medianprops={'lw':2}, whiskerprops={'lw':2},
#       4                     showcaps=True, showfliers=False, legend=False)
#       6 plt.tight_layout()
#       7 plt.title('SMYD5 expression at 6 hours ')
#
# NameError: name 'seaborn' is not defined

# %%
# REFAIRE SANS LA NORMALISATION

# %%
df = pandas.read_csv(file_directory + path + 'quantif_baf_mg132_blots.csv', sep = ",")
df = df.assign(SMYD5_norm = df['Smyd5'] / df['Lamin B1'])
df.head()
# Out:
#   conditions temperature           exp   Lamin B1      Smyd5  SMYD5_norm
# 0       DMSO        37°C  Experiment 1  12930.326   8487.669    0.656416
# 1        Baf        37°C  Experiment 1  19584.912  10569.962    0.539699
# 2      mg132        37°C  Experiment 1  21507.447  10002.841    0.465087
# 3  baf+mg132        37°C  Experiment 1  16880.083   8665.426    0.513352
# 4       DMSO        32°C  Experiment 1  10758.134  12192.134    1.133294

# %%
    #graph
    seaborn.catplot(x="conditions", y="SMYD5_norm", hue="temperature", aspect= 1.2, kind="box", palette = 'mako',
                    data = df, boxprops={'lw':2, 'alpha' : 0.8}, medianprops={'lw':2}, whiskerprops={'lw':2}, 
                    showcaps=True, showfliers=False, legend=False)

    plt.tight_layout()
    plt.xticks(rotation=45, ha= 'right')
    plt.ylabel('relative prot. expr.')
    plt.xlabel('')
    plt.legend(loc='center right', fontsize=20, bbox_to_anchor=(1.55, 0.5))
# Out:
# C:\Users\kja11\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\kja11\AppData\Local\Temp\ipykernel_22880\2312058170.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
#graph
seaborn.catplot(x="temperature", y="SMYD5_norm", hue='conditions', aspect= 1.2, kind="box", palette = 'mako',
                data = df, boxprops={'lw':2, 'alpha' : 0.8}, medianprops={'lw':2}, whiskerprops={'lw':2}, 
                showcaps=True, showfliers=False, legend=False)

plt.tight_layout()
plt.xticks(rotation=45, ha= 'right')
plt.ylabel('relative prot. expr.')
plt.xlabel('')
plt.legend(loc='center right', fontsize=20, bbox_to_anchor=(1.55, 0.5))
# Out:
# C:\Users\kja11\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\kja11\AppData\Local\Temp\ipykernel_22880\1462585359.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
